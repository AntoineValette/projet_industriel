# %%
import pandas as pd

# Lire un fichier Parquet
df = pd.read_parquet("/Users/guillaumeramirez/OneDrive - CentraleSupelec/Smart ETL - DOR/data/parquet/LogETL_20250130.csv_sub_2501301744.parquet")

# Afficher les premières lignes
df.head()
# Out:
#   Server version Client version                                  Model  \
# 0          6.0.0          6.0.0                      TMS/MF_TrajetsNew
# 1          6.0.0          6.0.0  TMS/MF_FactureFournisseursSansDetails
# 2          6.0.0          6.0.0             TMS/MF_FacturesSansDetails
# 3          6.0.0          6.0.0                             TMS/MF_SAV
# 4          6.0.0          6.0.0             TMS/MF_FactureFournisseurs
#
#             Type                              Insert mode  Rows added  \
# 0  Modèle simple  Mise à jour données / Insertion données       36861
# 1  Modèle simple  Mise à jour données / Insertion données         118
# 2  Modèle simple  Mise à jour données / Insertion données         369
# 3  Modèle simple  Mise à jour données / Insertion données         277
# 4  Modèle simple  Mise à jour données / Insertion données        1036
#
#    Rows updated  Rows deleted Rows in error Rows in warning  ...  \
# 0             0         36642          None            None  ...
# 1             0            44          None            None  ...
# 2             0            17          None            None  ...
# 3             0           191          None            None  ...
# 4             0           428          None            None  ...
#
#               Product Result       ETL_StartDateTime        Launcher_Name  \
# 0  MyReport Server BE     OK  None  14/03/2024 16:08  Launcher_Name_sub_5
# 1  MyReport Server BE     OK  None  14/03/2024 16:20  Launcher_Name_sub_5
# 2  MyReport Server BE     OK  None  14/03/2024 16:20  Launcher_Name_sub_5
# 3  MyReport Server BE     OK  None  14/03/2024 16:20  Launcher_Name_sub_5
# 4  MyReport Server BE     OK  None  14/03/2024 16:20  Launcher_Name_sub_5
#
#                                  Program_Id       Program_Name  \
# 0  ETL_b75838e4-8850-4d9a-ba25-4d541f4b237f    ETL Opti TMS 1h
# 1  ETL_9fdd54e0-2573-4307-af52-efe1c4c6a0c0  ETL Opti TMS Jour
# 2  ETL_9fdd54e0-2573-4307-af52-efe1c4c6a0c0  ETL Opti TMS Jour
# 3  ETL_9fdd54e0-2573-4307-af52-efe1c4c6a0c0  ETL Opti TMS Jour
# 4  ETL_9fdd54e0-2573-4307-af52-efe1c4c6a0c0  ETL Opti TMS Jour
#
#              Schedules_Id                       Schedules_Name  \
# 0  ETLPROGRAMMATIONBG7G6W   ETL Opti TMS toutes les 1h Lun-Sam
# 1  ETLPROGRAMMATIONLFMOU5  ETL Opti TMS-Compta 13h-16h Lun-Sam
# 2  ETLPROGRAMMATIONLFMOU5  ETL Opti TMS-Compta 13h-16h Lun-Sam
# 3  ETLPROGRAMMATIONLFMOU5  ETL Opti TMS-Compta 13h-16h Lun-Sam
# 4  ETLPROGRAMMATIONLFMOU5  ETL Opti TMS-Compta 13h-16h Lun-Sam
#
#   Schedules_StartDateTime
# 0        14/03/2024 15:41
# 1        14/03/2024 16:01
# 2        14/03/2024 16:01
# 3        14/03/2024 16:01
# 4        14/03/2024 16:01
#
# [5 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['Server version', 'Client version', 'Model', 'Type', 'Insert mode',
#        'Rows added', 'Rows updated', 'Rows deleted', 'Rows in error',
#        'Rows in warning', 'Columns', 'Date', 'Start time', 'End  time',
#        'Duration', 'Machine', 'Session', 'Project name', 'Product', 'Result',
#        '', 'ETL_StartDateTime', 'Launcher_Name', 'Program_Id', 'Program_Name',
#        'Schedules_Id', 'Schedules_Name', 'Schedules_StartDateTime'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289980 entries, 0 to 289979
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Server version           289980 non-null  object
#  1   Client version           289980 non-null  object
#  2   Model                    289980 non-null  object
#  3   Type                     289980 non-null  object
#  4   Insert mode              289980 non-null  object
#  5   Rows added               289980 non-null  int64
#  6   Rows updated             289980 non-null  int64
#  7   Rows deleted             289980 non-null  int64
#  8   Rows in error            0 non-null       object
#  9   Rows in warning          0 non-null       object
#  10  Columns                  289980 non-null  int64
#  11  Date                     289980 non-null  object
#  12  Start time               289980 non-null  object
#  13  End  time                289980 non-null  object
#  14  Duration                 289980 non-null  object
#  15  Machine                  289980 non-null  object
#  16  Session                  289980 non-null  object
#  17  Project name             289980 non-null  object
#  18  Product                  289980 non-null  object
#  19  Result                   289980 non-null  object
#  20                           0 non-null       object
#  21  ETL_StartDateTime        289980 non-null  object
#  22  Launcher_Name            289980 non-null  object
#  23  Program_Id               285302 non-null  object
#  24  Program_Name             289980 non-null  object
#  25  Schedules_Id             284286 non-null  object
#  26  Schedules_Name           284286 non-null  object
#  27  Schedules_StartDateTime  289980 non-null  object
# dtypes: int64(4), object(24)
# memory usage: 61.9+ MB

# %%
df.tail(10)
# Out:
#        Server version Client version                       Model  \
# 289970        6.1.0.2        6.1.0.2     GLPI/Printers_Cartridge
# 289971        6.1.0.2        6.1.0.2            GLPI/Techniciens
# 289972        6.1.0.2        6.1.0.2                  GLPI/Users
# 289973        6.1.0.2        6.1.0.2  GLPI/Attribut User Tickets
# 289974        6.1.0.2        6.1.0.2           DW/DSI/TotalUsers
# 289975        6.1.0.2        6.1.0.2              Divers/A temps
# 289976        6.1.0.2        6.1.0.2     DW/DSI/Atributs Tickets
# 289977        6.1.0.2        6.1.0.2          GLPI/Printers_Logs
# 289978        6.1.0.2        6.1.0.2                   GLPI/Logs
# 289979        6.1.0.2        6.1.0.2                GLPI/Tickets
#
#                  Type                                        Insert mode  \
# 289970  Modèle simple  Suppression table / Création table / Insertion...
# 289971  Modèle simple  Suppression table / Création table / Insertion...
# 289972  Modèle simple  Suppression table / Création table / Insertion...
# 289973  Modèle simple  Suppression table / Création table / Insertion...
# 289974   Modèle conso  Suppression table / Création table / Insertion...
# 289975   Modèle texte  Suppression table / Création table / Insertion...
# 289976   Modèle conso  Suppression table / Création table / Insertion...
# 289977  Modèle simple  Suppression table / Création table / Insertion...
# 289978  Modèle simple  Suppression table / Création table / Insertion...
# 289979  Modèle simple  Suppression table / Création table / Insertion...
#
#         Rows added  Rows updated  Rows deleted Rows in error Rows in warning  \
# 289970        1257             0             0          None            None
# 289971          47             0             0          None            None
# 289972        2563             0             0          None            None
# 289973       38881             0             0          None            None
# 289974        2610             0             0          None            None
# 289975        2191             0             0          None            None
# 289976       50742             0             0          None            None
# 289977      119404             0             0          None            None
# 289978        3486             0             0          None            None
# 289979       15688             0             0          None            None
#
#         ...             Product Result       ETL_StartDateTime  \
# 289970  ...  MyReport Server BE     OK  None  30/01/2025 15:05
# 289971  ...  MyReport Server BE     OK  None  30/01/2025 15:05
# 289972  ...  MyReport Server BE     OK  None  30/01/2025 15:05
# 289973  ...  MyReport Server BE     OK  None  30/01/2025 15:05
# 289974  ...  MyReport Server BE     OK  None  30/01/2025 15:05
# 289975  ...  MyReport Server BE     OK  None  30/01/2025 15:05
# 289976  ...  MyReport Server BE     OK  None  30/01/2025 15:05
# 289977  ...  MyReport Server BE     OK  None  30/01/2025 15:05
# 289978  ...  MyReport Server BE     OK  None  30/01/2025 15:05
# 289979  ...  MyReport Server BE     OK  None  30/01/2025 15:05
#
#               Launcher_Name                                Program_Id  \
# 289970  Launcher_Name_sub_5  ETL_e40758d2-53ad-48a5-86e9-07bc4b2c582d
# 289971  Launcher_Name_sub_5  ETL_e40758d2-53ad-48a5-86e9-07bc4b2c582d
# 289972  Launcher_Name_sub_5  ETL_e40758d2-53ad-48a5-86e9-07bc4b2c582d
# 289973  Launcher_Name_sub_5  ETL_e40758d2-53ad-48a5-86e9-07bc4b2c582d
# 289974  Launcher_Name_sub_5  ETL_e40758d2-53ad-48a5-86e9-07bc4b2c582d
# 289975  Launcher_Name_sub_5  ETL_e40758d2-53ad-48a5-86e9-07bc4b2c582d
# 289976  Launcher_Name_sub_5  ETL_e40758d2-53ad-48a5-86e9-07bc4b2c582d
# 289977  Launcher_Name_sub_5  ETL_e40758d2-53ad-48a5-86e9-07bc4b2c582d
# 289978  Launcher_Name_sub_5  ETL_e40758d2-53ad-48a5-86e9-07bc4b2c582d
# 289979  Launcher_Name_sub_5  ETL_e40758d2-53ad-48a5-86e9-07bc4b2c582d
#
#        Program_Name            Schedules_Id  \
# 289970     ETL GLPI  ETLPROGRAMMATIONC32E9W
# 289971     ETL GLPI  ETLPROGRAMMATIONC32E9W
# 289972     ETL GLPI  ETLPROGRAMMATIONC32E9W
# 289973     ETL GLPI  ETLPROGRAMMATIONC32E9W
# 289974     ETL GLPI  ETLPROGRAMMATIONC32E9W
# 289975     ETL GLPI  ETLPROGRAMMATIONC32E9W
# 289976     ETL GLPI  ETLPROGRAMMATIONC32E9W
# 289977     ETL GLPI  ETLPROGRAMMATIONC32E9W
# 289978     ETL GLPI  ETLPROGRAMMATIONC32E9W
# 289979     ETL GLPI  ETLPROGRAMMATIONC32E9W
#
#                                     Schedules_Name Schedules_StartDateTime
# 289970  ETL + Messenger Quotidien Lun-Sam 15h ALDI        30/01/2025 15:00
# 289971  ETL + Messenger Quotidien Lun-Sam 15h ALDI        30/01/2025 15:00
# 289972  ETL + Messenger Quotidien Lun-Sam 15h ALDI        30/01/2025 15:00
# 289973  ETL + Messenger Quotidien Lun-Sam 15h ALDI        30/01/2025 15:00
# 289974  ETL + Messenger Quotidien Lun-Sam 15h ALDI        30/01/2025 15:00
# 289975  ETL + Messenger Quotidien Lun-Sam 15h ALDI        30/01/2025 15:00
# 289976  ETL + Messenger Quotidien Lun-Sam 15h ALDI        30/01/2025 15:00
# 289977  ETL + Messenger Quotidien Lun-Sam 15h ALDI        30/01/2025 15:00
# 289978  ETL + Messenger Quotidien Lun-Sam 15h ALDI        30/01/2025 15:00
# 289979  ETL + Messenger Quotidien Lun-Sam 15h ALDI        30/01/2025 15:00
#
# [10 rows x 28 columns]

# %%
df['Program_Id'].nunique()
# Out:
# 51

# %%
df['ETL_StartDateTime']=pd.to_datetime(df['ETL_StartDateTime'])
# Out:
# /var/folders/f4/k8l34hms3tj0bm4tlr3mwg080000gn/T/ipykernel_76496/1772475934.py:1: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['ETL_StartDateTime']=pd.to_datetime(df['ETL_StartDateTime'])

# %%
df['ETL_StartDateTime'].head()
# Out:
# 0   2024-03-14 16:08:00
# 1   2024-03-14 16:20:00
# 2   2024-03-14 16:20:00
# 3   2024-03-14 16:20:00
# 4   2024-03-14 16:20:00
# Name: ETL_StartDateTime, dtype: datetime64[ns]

# %%
start_date = "2024-08-24 23:32:03"
end_date = "2024-10-15 23:31:49"

# %%
df_reduced = df[(df["ETL_StartDateTime"] >= start_date) & (df["ETL_StartDateTime"] <= end_date)]

# %%
df_reduced.head()
# Out:
#        Server version Client version  \
# 122840          6.0.2          6.0.2
# 122841          6.0.2          6.0.2
# 122842          6.0.2          6.0.2
# 122843          6.0.2          6.0.2
# 122844          6.0.2          6.0.2
#
#                                                     Model          Type  \
# 122840  Excel MyReport/Anomalies MyParc/V2/Anomalies P...  Modèle Excel
# 122841  Excel MyReport/Anomalies MyParc/V1/Anomalies V...  Modèle Excel
# 122842  Excel MyReport/Anomalies MyParc/V2/Anomalies M...  Modèle Excel
# 122843  Excel MyReport/Anomalies MyParc/V1/Anomalies P...  Modèle Excel
# 122844  Excel MyReport/Anomalies MyParc/V2/Anomalies V...  Modèle Excel
#
#               Insert mode  Rows added  Rows updated  Rows deleted  \
# 122840  Insertion données          33             0             0
# 122841  Insertion données           9             0             0
# 122842  Insertion données          15             0             0
# 122843  Insertion données          19             0             0
# 122844  Insertion données          11             0             0
#
#        Rows in error Rows in warning  ...             Product Result        \
# 122840          None            None  ...  MyReport Server BE     OK  None
# 122841          None            None  ...  MyReport Server BE     OK  None
# 122842          None            None  ...  MyReport Server BE     OK  None
# 122843          None            None  ...  MyReport Server BE     OK  None
# 122844          None            None  ...  MyReport Server BE     OK  None
#
#          ETL_StartDateTime        Launcher_Name  \
# 122840 2024-08-25 04:18:00  Launcher_Name_sub_5
# 122841 2024-08-25 04:18:00  Launcher_Name_sub_5
# 122842 2024-08-25 04:18:00  Launcher_Name_sub_5
# 122843 2024-08-25 04:18:00  Launcher_Name_sub_5
# 122844 2024-08-25 04:18:00  Launcher_Name_sub_5
#
#                                       Program_Id  \
# 122840  ETL_2bb27eb6-46ea-4208-9a6c-3074528a9285
# 122841  ETL_2bb27eb6-46ea-4208-9a6c-3074528a9285
# 122842  ETL_2bb27eb6-46ea-4208-9a6c-3074528a9285
# 122843  ETL_2bb27eb6-46ea-4208-9a6c-3074528a9285
# 122844  ETL_2bb27eb6-46ea-4208-9a6c-3074528a9285
#
#                              Program_Name            Schedules_Id  \
# 122840  ETL Anomalies V1-V2 MyParc Center  ETLPROGRAMMATIONWCLOA6
# 122841  ETL Anomalies V1-V2 MyParc Center  ETLPROGRAMMATIONWCLOA6
# 122842  ETL Anomalies V1-V2 MyParc Center  ETLPROGRAMMATIONWCLOA6
# 122843  ETL Anomalies V1-V2 MyParc Center  ETLPROGRAMMATIONWCLOA6
# 122844  ETL Anomalies V1-V2 MyParc Center  ETLPROGRAMMATIONWCLOA6
#
#                                            Schedules_Name  \
# 122840  ETL + Messenger Quotidien Lun-Dim vers Serveur...
# 122841  ETL + Messenger Quotidien Lun-Dim vers Serveur...
# 122842  ETL + Messenger Quotidien Lun-Dim vers Serveur...
# 122843  ETL + Messenger Quotidien Lun-Dim vers Serveur...
# 122844  ETL + Messenger Quotidien Lun-Dim vers Serveur...
#
#        Schedules_StartDateTime
# 122840        25/08/2024 04:16
# 122841        25/08/2024 04:16
# 122842        25/08/2024 04:16
# 122843        25/08/2024 04:16
# 122844        25/08/2024 04:16
#
# [5 rows x 28 columns]

# %%
df_reduced["Hour"] = df_reduced["ETL_StartDateTime"].dt.floor("h")
# Out:
# /var/folders/f4/k8l34hms3tj0bm4tlr3mwg080000gn/T/ipykernel_76496/1418444260.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced["Hour"] = df_reduced["ETL_StartDateTime"].dt.floor("h")

# %%
df_reduced.head()
# Out:
#        Server version Client version  \
# 122840          6.0.2          6.0.2
# 122841          6.0.2          6.0.2
# 122842          6.0.2          6.0.2
# 122843          6.0.2          6.0.2
# 122844          6.0.2          6.0.2
#
#                                                     Model          Type  \
# 122840  Excel MyReport/Anomalies MyParc/V2/Anomalies P...  Modèle Excel
# 122841  Excel MyReport/Anomalies MyParc/V1/Anomalies V...  Modèle Excel
# 122842  Excel MyReport/Anomalies MyParc/V2/Anomalies M...  Modèle Excel
# 122843  Excel MyReport/Anomalies MyParc/V1/Anomalies P...  Modèle Excel
# 122844  Excel MyReport/Anomalies MyParc/V2/Anomalies V...  Modèle Excel
#
#               Insert mode  Rows added  Rows updated  Rows deleted  \
# 122840  Insertion données          33             0             0
# 122841  Insertion données           9             0             0
# 122842  Insertion données          15             0             0
# 122843  Insertion données          19             0             0
# 122844  Insertion données          11             0             0
#
#        Rows in error Rows in warning  ...  Result         ETL_StartDateTime  \
# 122840          None            None  ...      OK  None 2024-08-25 04:18:00
# 122841          None            None  ...      OK  None 2024-08-25 04:18:00
# 122842          None            None  ...      OK  None 2024-08-25 04:18:00
# 122843          None            None  ...      OK  None 2024-08-25 04:18:00
# 122844          None            None  ...      OK  None 2024-08-25 04:18:00
#
#               Launcher_Name                                Program_Id  \
# 122840  Launcher_Name_sub_5  ETL_2bb27eb6-46ea-4208-9a6c-3074528a9285
# 122841  Launcher_Name_sub_5  ETL_2bb27eb6-46ea-4208-9a6c-3074528a9285
# 122842  Launcher_Name_sub_5  ETL_2bb27eb6-46ea-4208-9a6c-3074528a9285
# 122843  Launcher_Name_sub_5  ETL_2bb27eb6-46ea-4208-9a6c-3074528a9285
# 122844  Launcher_Name_sub_5  ETL_2bb27eb6-46ea-4208-9a6c-3074528a9285
#
#                              Program_Name            Schedules_Id  \
# 122840  ETL Anomalies V1-V2 MyParc Center  ETLPROGRAMMATIONWCLOA6
# 122841  ETL Anomalies V1-V2 MyParc Center  ETLPROGRAMMATIONWCLOA6
# 122842  ETL Anomalies V1-V2 MyParc Center  ETLPROGRAMMATIONWCLOA6
# 122843  ETL Anomalies V1-V2 MyParc Center  ETLPROGRAMMATIONWCLOA6
# 122844  ETL Anomalies V1-V2 MyParc Center  ETLPROGRAMMATIONWCLOA6
#
#                                            Schedules_Name  \
# 122840  ETL + Messenger Quotidien Lun-Dim vers Serveur...
# 122841  ETL + Messenger Quotidien Lun-Dim vers Serveur...
# 122842  ETL + Messenger Quotidien Lun-Dim vers Serveur...
# 122843  ETL + Messenger Quotidien Lun-Dim vers Serveur...
# 122844  ETL + Messenger Quotidien Lun-Dim vers Serveur...
#
#        Schedules_StartDateTime                Hour
# 122840        25/08/2024 04:16 2024-08-25 04:00:00
# 122841        25/08/2024 04:16 2024-08-25 04:00:00
# 122842        25/08/2024 04:16 2024-08-25 04:00:00
# 122843        25/08/2024 04:16 2024-08-25 04:00:00
# 122844        25/08/2024 04:16 2024-08-25 04:00:00
#
# [5 rows x 29 columns]

# %%
print(df_reduced['Insert mode'].nunique())
df_reduced['Insert mode'].unique()
# Out:
# 3
# array(['Insertion données',
#        'Suppression table / Création table / Insertion données',
#        'Mise à jour données / Insertion données'], dtype=object)

# %%
df_grouped = df_reduced.groupby("Hour").agg(
    nb_operations=("Insert mode", "count"),  # Nombre total de lignes dans l'heure
    rows_added=("Rows added", "sum"),      # Somme des lignes ajoutées
    rows_updated=("Rows updated", "sum"),  # Somme des mises à jour
    rows_deleted=("Rows deleted", "sum")   # Somme des suppressions
).reset_index()

# %%
df_grouped.head(100)
# Out:
#                   Hour  nb_operations  rows_added  rows_updated  rows_deleted
# 0  2024-08-25 04:00:00             11      200563             0             0
# 1  2024-08-25 10:00:00             30     8333604             0             0
# 2  2024-08-25 12:00:00             16     6207430             0             0
# 3  2024-08-25 22:00:00             16      192159             0             0
# 4  2024-08-25 23:00:00            408   474322006             0         18598
# ..                 ...            ...         ...           ...           ...
# 95 2024-08-31 14:00:00             47    23817308             0             0
# 96 2024-08-31 15:00:00             11     7702853             0             0
# 97 2024-08-31 16:00:00             42    10951118             0             0
# 98 2024-08-31 17:00:00             11     7703874             0             0
# 99 2024-08-31 20:00:00             11     7704988             0             0
#
# [100 rows x 5 columns]

# %%
df_grouped.shape
# Out:
# (769, 5)

# %%
print(df_reduced['Program_Name'].nunique())
df_reduced['Program_Name'].unique()
# Out:
# 31
# array(['ETL Anomalies V1-V2 MyParc Center', 'ETL Tachy', 'ETL Achats',
#        'ETL BEXT', 'ETL Stock Article Hub Aldi', 'ETL Parc Production',
#        'Toutes les semaines, le dimanche', 'ETL Histo Emballages',
#        'ETL GLPI', 'ETL Histo GLPI', 'Tous les jours', 'ETL BAG',
#        'ETL Marges', 'ETL Taxation', 'ETL_API_JWT', 'ETL Chargement PJ',
#        'ETL sur ordre', 'ETL Center Finance', 'ETL Projection',
#        'ETL JIRA', 'ETL Heures Chauffeurs', 'ETL Volumes CRF ',
#        'ETL Conso Tiers', 'ETL CRF', 'ETL Stock Hub Aldi',
#        'ETL Historisation Stock', 'ETL KPI ALDI',
#        'ETL Affectation Salariés', 'ETL_Benchmark',
#        'ETL Vue Heures Agrégées', 'ETL Compta Analytique'], dtype=object)

# %%
top_program = df_reduced['Program_Name'].value_counts()
top_program = top_program.head(10)
print(top_program)
# Out:
# Program_Name
# Tous les jours           20885
# ETL BEXT                 10537
# ETL Chargement PJ         6005
# ETL GLPI                  4536
# ETL Heures Chauffeurs     2149
# ETL sur ordre              806
# ETL KPI ALDI               636
# ETL Taxation               518
# ETL BAG                    444
# ETL JIRA                   385
# Name: count, dtype: int64
